# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelrucci7/deep-learning-course/blob/main/colab/TextClassficationAmorePauraSpaventoDelusione.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Custom Traning

# %%
# %%capture
# !pip install transformers datasets evaluate

# %% [markdown]
# ## Dataset

# %%
from datasets import DatasetDict, Dataset
# 0: Paura
# 1: Amore
# 2: Spavento
# 3: Delusione

classes = {
    0: "Paura",
    1: "Amore",
    2: "Spavento",
    3: "Delusione"
}
sentences_paura = [
        "Il buio della stanza mi avvolse, facendomi trattenere il respiro per timore di ciò che poteva nascondersi.",
        "Le sue mani tremavano incontrollabilmente mentre ascoltava i passi avvicinarsi alla porta.",
        "L'idea di parlare davanti a centinaia di persone mi paralizzava completamente.",
        "Ad ogni scricchiolio del pavimento, il mio cuore saltava un battito.",
        "L'incertezza del futuro lo teneva sveglio notte dopo notte.",
        "La vista del precipizio le fece girare la testa, incapace di muoversi.",
        "Quando il dottore chiese di parlare in privato, sentì il sangue gelarsi nelle vene.",
        "Il suono della sirena in lontananza risvegliò in lei antiche angosce.",
        "La notizia della tempesta in arrivo spinse gli abitanti a barricarsi in casa.",
        "Non riusciva a controllare il battito accelerato del cuore mentre aspettava i risultati.",
        "Il pensiero di fallire ancora una volta lo paralizzava completamente.",
        "Un brivido le percorse la schiena quando sentì la porta chiudersi alle sue spalle.",
        "Ogni ombra sembrava nascondere una minaccia nella casa deserta.",
        "L'aereo iniziò a tremare violentemente, facendola aggrappare al sedile con terrore.",
        "Guardava costantemente sopra la spalla, sentendosi osservato da occhi invisibili.",
        "Il messaggio criptico sul telefono le fece temere il peggio per sua figlia.",
        "La sensazione di essere seguita cresceva ad ogni passo nel vicolo buio.",
        "Leggere le statistiche della malattia lo fece sprofondare in un abisso di paura.",
        "Il silenzio assordante della foresta amplificava ogni suo timore.",
        "Sentire quella voce familiare, dopo tanto tempo, risvegliò in lui il terrore del passato.",
        "I suoi incubi si facevano sempre più realistici, al punto che temeva di addormentarsi.",
        "La nebbia fitta nascondeva la strada, accrescendo la sua paura di perdersi per sempre.",
        "Il rumore di passi che la seguivano accelerò il battito del suo cuore impaurito.",
        "Le notizie del telegiornale alimentavano la sua ansia per il futuro incerto.",
        "Il buio del sottopassaggio sembrava inghiottirla, passo dopo passo.",
        "L'inspiegabile spostamento degli oggetti in casa la terrorizzava ogni notte.",
        "La diagnosi incerta lo lasciò in balia dell'angoscia più profonda.",
        "Il graffio alla finestra del secondo piano le fece dubitare di essere sola in casa.",
        "L'improvviso silenzio della foresta era più spaventoso di qualsiasi rumore.",
        "La sua fobia dei ragni trasformava ogni ombra in un potenziale pericolo.",
        "Il respiro affannoso tradiva il terrore che cercava disperatamente di nascondere.",
        "Ogni volta che il telefono squillava a tarda notte, immaginava la peggiore delle notizie.",
        "La bambola seduta sul letto sembrava osservarla con occhi vivi e malvagi.",
        "Le voci sussurrate oltre la porta chiusa lo immobilizzarono sul posto.",
        "Il pensiero di incontrarlo nuovamente dopo quanto accaduto la terrorizzava.",
        "La sua claustrofobia trasformò l'ascensore in una trappola soffocante.",
        "L'ululato del vento tra gli alberi sembrava un lamento spettrale.",
        "Non riusciva a liberarsi dall'immagine dell'incidente, che ritornava a tormentarla.",
        "Le ombre proiettate dai rami sulla parete sembravano artigli pronti ad afferrarla.",
        "La lettura del testamento gli fece temere rivelazioni che avrebbero distrutto ogni certezza.",
        "I suoi occhi scrutavano nervosamente ogni angolo della stanza sconosciuta.",
        "La paura di deludere suo padre guidava ogni sua scelta, anche le più insignificanti.",
        "Contare i battiti accelerati del cuore diventò il suo modo per misurare il terrore.",
        "La figura indistinta oltre la finestra appannata paralizzò ogni suo muscolo.",
        "La montagna di debiti cresceva come un'ombra minacciosa sul suo futuro.",
        "La porta chiusa a chiave dall'esterno trasformò la stanza in una prigione spaventosa.",
        "L'idea di rimanere completamente solo lo terrorizzava più di qualsiasi altra cosa.",
        "Le cicatrici sul braccio erano un costante promemoria di ciò che più temeva.",
        "La maschera antigas nell'armadio testimoniava la sua paranoia crescente.",
        "Ogni rumore metallico le ricordava l'incidente che aveva cambiato la sua vita.",
        "Il fischio del vento attraverso le persiane sembrava un sinistro avvertimento.",
        "La lettera anonima conteneva minacce che gli tolsero il sonno per settimane.",
        "Il corridoio buio dell'ospedale abbandonato amplificava ogni suo timore irrazionale.",
        "La sensazione di una presenza invisibile nella stanza la paralizzava nel letto.",
        "Lo scricchiolio delle assi del pavimento tradiva la presenza di un intruso.",
        "Il suono di unghie che grattavano contro il muro la fece raggelare sotto le coperte.",
        "La sua mente continuava a immaginare scenari catastrofici per il colloquio imminente.",
        "Controllava ossessivamente che la porta fosse chiusa, incapace di fidarsi della propria memoria.",
        "L'ombra del ramo proiettata sulla parete sembrava una mano pronta ad afferrarla.",
        "La radio che si accese da sola nel cuore della notte lo fece saltare dal letto terrorizzato.",
        "Il fascio di luce della torcia rivelava appena il sentiero, lasciando l'ignoto tutt'intorno.",
        "Il sibilo del serpente nascosto tra le foglie accelerò il suo battito cardiaco.",
        "La tempesta elettrica illuminava la stanza con flash spettrali, alimentando le sue paure.",
        "La sensazione di essere osservato persisteva anche nelle stanze vuote della casa.",
        "I suoi occhi si rifiutavano di guardare lo specchio, temendo ciò che avrebbero potuto vedere.",
        "Il cigolio della vecchia altalena in giardino, senza vento, le gelò il sangue nelle vene.",
        "Ogni suono nella vecchia casa veniva amplificato dal silenzio e dalla sua paura crescente.",
        "Il pensiero di affrontare la folla lo paralizzava, rendendogli impossibile uscire di casa.",
        "L'ombra che si allungava sul muro sembrava seguire ogni suo movimento.",
        "L'acqua scura del lago nascondeva profondità che non osava immaginare.",
        "La nebbia che avvolgeva la strada rendeva impossibile vedere oltre pochi metri.",
        "Il manichino nell'angolo del negozio sembrava seguirla con lo sguardo vuoto.",
        "Il ronzio elettrico proveniente dal seminterrato suggeriva pericoli nascosti.",
        "La notizia dell'epidemia in avvicinamento scatenò il panico più profondo.",
        "Ogni creatura notturna diventava un mostro nei suoi occhi terrorizzati.",
        "I passi pesanti al piano di sopra le ricordarono che doveva essere sola in casa.",
        "Il soffio gelido sulla nuca lo fece voltare di scatto, con gli occhi sbarrati dal terrore.",
        "Immaginava orrori indescrivibili nascosti nell'oscurità sotto il letto.",
        "La radio trasmetteva solo statica, aumentando la sensazione di isolamento e pericolo.",
        "L'ululato distante di un lupo risvegliò paure ancestrali che non sapeva di avere.",
        "Lo scricchiolio della porta che si apriva lentamente la inchiodò contro il muro.",
        "Ogni sussurro del vento sembrava portare messaggi di imminente sventura.",
        "Il rumore di passi sul ghiaietto del vialetto la svegliò nel cuore della notte.",
        "La vecchia fotografia mostrava una figura sfocata che non doveva essere lì.",
        "Le impronte bagnate sul pavimento conducevano alla stanza dove nessuno era entrato.",
        "Il profondo pozzo nero sembrava pronto a inghiottirlo nelle sue viscere.",
        "La ragnatela che le sfiorò il viso nell'oscurità le strappò un grido soffocato.",
        "Ripensare a quella notte gli faceva ancora accelerare il cuore dalla paura.",
        "Le voci indistinte oltre la parete sottile alimentavano la sua paranoia.",
        "L'ombra di qualcosa di inumano si allungò sulla parete di fronte a lei.",
        "Il pensiero di quella creatura sotto il letto gli impediva di allungare i piedi oltre il materasso.",
        "Le tracce di sangue sul pavimento conducevano verso la stanza buia in fondo al corridoio.",
        "La leggenda locale del fantasma sembrava improvvisamente molto più credibile quella notte.",
        "L'urlo disumano proveniente dal bosco la fece tremare sotto le coperte.",
        "I suoi occhi scrutavano continuamente l'oscurità, cercando di anticipare il pericolo."
        ]
sentences_amore = [
        "Ogni volta che sorrideva, sentiva il mondo illuminarsi attorno a sé.",
        "La distanza tra loro sembrava scomparire quando si scambiavano messaggi.",
        "Il semplice sfiorarsi delle mani creava scintille impossibili da ignorare.",
        "Avrebbe attraversato oceani solo per vederla felice ancora una volta.",
        "Nella sua voce trovava il conforto che aveva cercato per tutta la vita.",
        "Il pensiero di svegliarsi accanto a lei ogni mattina lo riempiva di gioia.",
        "Le preparò la colazione preferita, godendo dell'anticipazione della sua reazione.",
        "Ascoltava con interesse ogni parola, come se fosse la più importante del mondo.",
        "Nonostante gli anni passati insieme, il suo cuore ancora batteva più forte quando lo vedeva.",
        "Nel suo abbraccio trovava un rifugio sicuro da tutte le tempeste della vita.",
        "Memorizzò ogni dettaglio del suo viso, come un pittore davanti al più bello dei paesaggi.",
        "La canzone che suonava alla radio le ricordava il loro primo ballo insieme.",
        "Conservava gelosamente il biglietto scritto a mano che le aveva dato anni prima.",
        "I chilometri di distanza non potevano spegnere ciò che provava per lei.",
        "Si sorprese a sorridere al telefono, anche se l'altro non poteva vederlo.",
        "Ogni suo difetto era, ai suoi occhi, una ragione in più per amarla.",
        "Il profumo dei suoi capelli risvegliava ricordi di momenti perfetti insieme.",
        "Sapeva esattamente come preparare il tè nel modo in cui le piaceva.",
        "Leggere il suo nome sullo schermo del telefono le faceva battere il cuore all'impazzata.",
        "Attese pazientemente per ore in aeroporto, solo per poterla riabbracciare.",
        "Conosceva a memoria tutte le sue espressioni e poteva interpretarne ogni sfumatura.",
        "Le leggeva poesie durante le notti insonni, solo per sentirla respirare accanto a sé.",
        "Ogni canzone gli ricordava un momento speciale della loro storia insieme.",
        "Si sentiva completo solo quando i loro sguardi si incrociavano nella stanza affollata.",
        "La sua risata era diventata il suono preferito in assoluto.",
        "Percorreva ogni giorno la stessa strada, sperando di incontrarla per caso.",
        "Il loro amore era come un porto sicuro in un mare tempestoso.",
        "Le scriveva lettere che non avrebbe mai spedito, riversando tutto il suo cuore.",
        "Collezionava piccoli oggetti che le ricordavano momenti condivisi insieme.",
        "Osservava segretamente le foto della loro vacanza quando la nostalgia si faceva sentire.",
        "Sentire il suo nome pronunciato da altri bastava a fargli perdere il filo del discorso.",
        "Poteva passare ore a guardare le stelle, immaginando di condividere quel momento con lei.",
        "Anche dopo anni, ricordava esattamente il vestito che indossava il giorno in cui si erano conosciuti.",
        "La chiamata notturna era diventata un rituale prezioso che nessuno dei due voleva interrompere.",
        "Il piccolo difetto nel suo sorriso era la cosa più affascinante che avesse mai visto.",
        "Teneva sempre un posto libero accanto a sé, come se potesse apparire da un momento all'altro.",
        "I suoi pensieri tornavano sempre a lei, come un fiume che conosce solo la strada verso il mare.",
        "Il sapore del gelato al pistacchio gli ricordava il loro primo appuntamento.",
        "Imparò a cucinare solo per vedere il suo sorriso di apprezzamento.",
        "Le mandava messaggi durante la giornata solo per dirle quanto la pensava.",
        "Il tempo si fermava quando si perdeva nei suoi occhi color ambra.",
        "Conservava una lista mentale di tutti i film che voleva guardare con lei un giorno.",
        "Il suo cuore riconosceva la sua presenza prima ancora che apparisse nella stanza.",
        "Pianificava viaggi immaginari in luoghi che avevano sempre sognato di visitare insieme.",
        "Cercava il suo profumo in ogni stanza, anche quando sapeva che non c'era.",
        "Sentire la sua voce assonnata al telefono era il modo perfetto per iniziare la giornata.",
        "Ricordava a memoria tutte le date importanti della loro storia, anche le più insignificanti.",
        "I suoi occhi cercavano sempre il suo volto in ogni folla.",
        "Il tocco delle sue dita sulla pelle era come una carezza dell'anima.",
        "La loro connessione andava oltre le parole, comunicando spesso solo con gli sguardi.",
        "La melodia che fischiettava mentre cucinava era quella della loro canzone.",
        "Si ritrovò a cambiare strada solo per passare davanti al locale dove si erano conosciuti.",
        "Aveva memorizzato il modo in cui gli occhi di lei si illuminavano quando era felice.",
        "Ogni nuovo libro che leggeva immaginava di condividerlo con lei un giorno.",
        "Il suono della sua risata poteva scacciare anche il più cupo dei suoi pensieri.",
        "Conservava come un tesoro la ciocca di capelli che gli aveva donato anni prima.",
        "Il modo in cui pronunciava il suo nome era diverso da qualsiasi altra persona.",
        "Teneva sotto il cuscino la felpa che gli aveva prestato, ancora impregnata del suo profumo.",
        "Il cielo stellato gli ricordava sempre la notte in cui si erano dichiarati i loro sentimenti.",
        "Ogni volta che cucinava il suo piatto preferito, sentiva la sua presenza accanto a sé.",
        "Continuava a guardare film romantici, immaginando di essere il protagonista con lei.",
        "Il suo cuore batteva ancora all'impazzata quando la vedeva dopo una lunga assenza.",
        "La prima pagina di ogni suo quaderno portava le iniziali di lei, nascoste in un disegno.",
        "Si sorprendeva a cercare il suo profilo nelle sconosciute che incrociava per strada.",
        "Conosceva a memoria ogni sfumatura della sua voce e cosa significasse ciascuna di esse.",
        "Anche il caffè aveva un sapore diverso quando lo bevevano insieme la mattina.",
        "La luce del tramonto illuminava il suo viso nel modo perfetto, come in un dipinto rinascimentale.",
        "Il rumore della pioggia gli ricordava le serate passate insieme sotto le coperte.",
        "Teneva il telefono sempre vicino, per non perdere neanche una sua chiamata.",
        "Conservava gelosamente il biglietto del cinema del loro primo appuntamento.",
        "Ogni domenica mattina preparava i pancake esattamente come piacevano a lei.",
        "Il gesto con cui si sistemava i capelli dietro l'orecchio lo faceva innamorare ogni volta.",
        "Ascoltava le sue playlist per sentirsi più vicino a lei durante i viaggi di lavoro.",
        "Il modo in cui lei intrecciava le dita con le sue era una forma di comunicazione tutta loro.",
        "La sua città preferita era diventata quella in cui lei era nata, senza nemmeno esserci stato.",
        "Il calendario era pieno di piccoli cuori nei giorni in cui si sarebbero rivisti.",
        "Ricordava perfettamente il punto esatto dove si erano incontrati per la prima volta.",
        "Ogni nuovo ristorante che scopriva pensava sempre a quanto le sarebbe piaciuto.",
        "Teneva un diario dove annotava ogni piccolo momento significativo trascorso insieme.",
        "La sensazione delle sue braccia attorno alla vita era il più grande conforto che conoscesse.",
        "Credeva di riconoscere la sua silhouette in ogni donna che camminava nella sua direzione.",
        "L'odore della sua pelle era diventato il profumo più inebriante che conoscesse.",
        "Anche dopo anni, ricordava esattamente le parole che si erano scambiati il primo giorno.",
        "Contava i giorni che mancavano al loro prossimo incontro come un bambino aspetta Natale.",
        "Aveva imparato la sua lingua madre solo per poterle sussurrare parole d'amore più intime.",
        "Il modo in cui lei pronunciava il suo nome faceva vibrare qualcosa di profondo dentro di lui.",
        "Collezionava cartoline di tutti i luoghi che volevano visitare insieme un giorno.",
        "Ogni sua foto sul telefono era accompagnata da un ricordo specifico di quel momento.",
        "Il gesto con cui si mordeva il labbro quando era concentrata lo faceva impazzire.",
        "Aveva memorizzato ogni piccola abitudine, dai gusti del gelato agli orari del sonno.",
        "La musica che suonava nel locale divenne per sempre la colonna sonora del loro amore.",
        "Sapeva esattamente quale libro regalarle solo guardando il suo umore.",
        "Il modo in cui inclinavano le teste nello stesso momento quando si baciavano sembrava una danza perfetta.",
        "Tornava sempre allo stesso parco, sperando di rivivere il momento del loro primo incontro.",
        "La piccola ruga che appariva quando sorrideva era il dettaglio più bello del suo viso.",
        "Ogni canzone d'amore sembrava scritta appositamente per descrivere ciò che provava per lei."]
sentences_spavento = [
        "Il rumore improvviso alle sue spalle la fece saltare dalla sedia.",
        "L'ombra proiettata sul muro le strappò un grido di terrore.",
        "Il clacson dell'auto lo colse di sorpresa, facendogli rovesciare il caffè.",
        "Si svegliò di soprassalto, con il cuore che batteva all'impazzata per l'incubo.",
        "La porta sbattuta dal vento la lasciò senza fiato per alcuni secondi.",
        "Il vetro frantumato ai suoi piedi lo fece indietreggiare d'istinto.",
        "Il ringhio del cane nell'oscurità la immobilizzò sul posto.",
        "L'apparizione improvvisa del suo riflesso nello specchio le fece sfuggire un urlo.",
        "Lo squillo del telefono nel silenzio della notte lo fece sobbalzare.",
        "Il tuono fragoroso la fece nascondere sotto le coperte in un attimo.",
        "Un ramo colpì improvvisamente il finestrino, facendola gridare per lo spavento.",
        "La maschera che apparve da dietro la tenda gli strappò un urlo incontrollato.",
        "Il serpente che strisciava vicino alla sua scarpa la fece balzare all'indietro.",
        "Il flash improvviso della fotocamera lo fece sussultare visibilmente.",
        "Il mannequin nel negozio buio sembrava una figura umana, facendola trasalire.",
        "L'allarme antincendio suonò all'improvviso, facendole cadere il piatto dalle mani.",
        "La mano che afferrò la sua caviglia da sotto il letto la fece urlare terrorizzata.",
        "La figura che emerse improvvisamente dalla nebbia lo fece frenare bruscamente.",
        "Il libro caduto dallo scaffale in biblioteca la fece sobbalzare di paura.",
        "Il grido improvviso del bambino lo fece quasi cadere dalla scala.",
        "Il coperchio della scatola si aprì da solo, facendola saltare all'indietro con un grido.",
        "Il pipistrello che volò rasente alla sua testa le strappò un urlo acuto.",
        "La mano fredda sulla spalla in una stanza che credeva vuota lo fece voltare di scatto.",
        "L'esplosione del petardo sotto la panchina la fece schizzare in piedi terrorizzata.",
        "Il manichino caduto dall'espositore sembrò per un attimo una persona vera.",
        "L'improvviso spegnimento delle luci in cantina lo lasciò paralizzato dal terrore.",
        "La porta dell'armadio che si aprì lentamente da sola le fece trattenere il respiro.",
        "Il tonfo sordo proveniente dal piano superiore disabitato lo fece gelare sul posto.",
        "L'urlo della civetta nella notte la fece sobbalzare violentemente.",
        "Il volto sconosciuto che apparve alla finestra gli strappò un grido di paura.",
        "La sirena dell'ambulanza che passò a tutta velocità la fece quasi cadere dallo sgabello.",
        "Il respiro caldo sulla nuca in una stanza che credeva vuota lo pietrificò.",
        "Il forte bussare alla porta a mezzanotte la fece svegliare con un grido soffocato.",
        "L'ombra che si mosse nell'angolo dell'occhio lo fece girare di scatto.",
        "La bambola che cambiò posizione quando tornò nella stanza le fece battere forte il cuore.",
        "Il rapido movimento tra i cespugli lo fece indietreggiare impaurito.",
        "Il gatto che saltò improvvisamente sul davanzale la fece urlare per lo spavento.",
        "Il quadro che cadde dal muro senza apparente motivo lo fece sobbalzare violentemente.",
        "Il brusco risveglio causato dalla sveglia le strappò un grido acuto.",
        "Il rumore di vetri infranti al piano di sotto lo fece alzare dal letto con il cuore in gola.",
        "Il palloncino che scoppiò inaspettatamente la fece saltare dalla sedia con un urlo.",
        "La figura scura intravista nel corridoio buio lo fece paralizzare sul posto.",
        "L'improvvisa fiammata dal fornello le fece lasciare cadere la padella con un grido.",
        "L'auto che sbucò all'improvviso dal vicolo lo fece scattare all'indietro per evitarla.",
        "Il ghiaccio che si ruppe sotto i suoi piedi le strappò un urlo di terrore puro.",
        "Lo scoppio improvviso della lampadina lo fece rannicchiare istintivamente.",
        "Il forte sibilo dalla caldaia la fece correre fuori dalla stanza in preda al panico.",
        "La saetta che colpì l'albero vicino gli strappò un grido incontrollato.",
        "L'improvviso abbaiare del cane nel silenzio la fece quasi cadere dalla sedia.",
        "Il suono metallico proveniente dal sottotetto lo lasciò immobile, con il fiato sospeso.",
        "La luce della torcia che illuminò il suo viso all'improvviso la fece sussultare violentemente.",
        "Il filo elettrico che sfrigolò pericolosamente lo fece balzare all'indietro istintivamente.",
        "L'orso apparso sul sentiero la paralizzò completamente, con il cuore in gola.",
        "Il fischio improvviso della pentola a pressione lo fece saltare letteralmente in aria.",
        "La mano del manichino che sembrava muoversi da sola le fece trattenere un urlo.",
        "Il copertone che esplose mentre guidava lo fece stringere il volante con terrore.",
        "Lo schermo del computer che si spense di colpo la fece sobbalzare nella stanza buia.",
        "L'insetto che atterrò sul suo braccio lo fece agitare freneticamente per scacciarlo.",
        "La porta del frigorifero che si chiuse da sola le fece sfuggire un grido acuto.",
        "Il telefono che vibrò inaspettatamente nella tasca lo fece saltare visibilmente.",
        "Il ragno che calò dal soffitto proprio davanti al suo viso la fece indietreggiare urlando.",
        "L'improvvisa accelerazione dell'ascensore gli fece perdere l'equilibrio momentaneamente.",
        "Il ramo che graffiò la finestra durante la notte la fece svegliare terrorizzata.",
        "La bicicletta che sfrecciò accanto a lui sul marciapiede lo fece saltare di lato con un grido.",
        "Il giocattolo che si attivò da solo nel cuore della notte la fece sedere di scatto nel letto.",
        "Il drone che apparve improvvisamente sopra la sua testa lo fece accucciarsi istintivamente.",
        "Lo scatto della trappola per topi la fece sobbalzare nervosamente.",
        "L'acqua gelida che investì improvvisamente il suo corpo gli strappò un urlo di sorpresa.",
        "Il vecchio pavimento che cedette sotto i suoi passi la fece gridare terrorizzata.",
        "Il fischio del treno che passò a tutta velocità lo fece saltare indietro istintivamente.",
        "La porta tagliafuoco che si chiuse automaticamente alle sue spalle la fece rabbrividire.",
        "Il cartellone pubblicitario che cadde davanti alla sua auto lo costrinse a frenare bruscamente.",
        "L'ombra che si mosse rapidamente nella periferia del suo campo visivo la fece voltare di scatto.",
        "L'urto improvviso contro il tavolo nel buio gli fece sfuggire un'imprecazione spaventata.",
        "La maschera appesa alla parete che sembrò muoversi la fece indietreggiare terrorizzata.",
        "Il blackout improvviso lo lasciò immobile nel buio più completo, con il cuore accelerato.",
        "L'allarme dell'auto che scattò all'improvviso la fece sobbalzare sul marciapiede.",
        "La tazza che cadde dalla mensola senza apparente motivo lo fece girare di scatto.",
        "Il ramo secco che si spezzò sotto i suoi piedi le provocò un sussulto di paura.",
        "L'urlo proveniente dalla casa accanto lo fece correre alla finestra con il cuore in gola.",
        "La fiamma della candela che si spense all'improvviso la lasciò nel buio più totale.",
        "Il colpo secco contro la finestra lo fece saltare dalla poltrona con un grido soffocato.",
        "Il cavallo imbizzarrito che galoppò nella sua direzione la fece correre al riparo urlando.",
        "Il microfono che produsse un acuto feedback lo fece indietreggiare con un sussulto.",
        "La scatola impacchettata che si mosse da sola sul tavolo le fece trattenere il respiro.",
        "L'impatto improvviso con lo specchio d'acqua lo fece gridare per lo shock termico.",
        "La raffica di vento che spalancò la finestra la fece sussultare visibilmente.",
        "Il contatto inaspettato con qualcosa di viscido gli fece ritirare la mano con disgusto e paura.",
        "L'ululato del lupo nella notte la fece stringere nel sacco a pelo tremando.",
        "Il colpo di tosse alle sue spalle in quella che credeva una stanza vuota lo pietrificò sul posto.",
        "La maschera antigas appesa al muro sembrò fissarla improvvisamente, facendola trasalire.",
        "Il pavimento che scricchiolò sotto i suoi passi lo fece fermare immediatamente, in ascolto.",
        "L'onda improvvisa che travolse la barca la fece aggrappare disperatamente al bordo.",
        "L'improvviso bagliore nel cielo notturno lo fece alzare di scatto dal letto."]
sentences_delusione = [
        "Le lacrime scivolarono silenziosamente mentre fissava la lettera di licenziamento.",
        "Il regalo non aperto rimase sulla tavola come simbolo di un'amicizia ormai spenta.",
        "Contemplò il bicchiere vuoto, proprio come le promesse che gli erano state fatte.",
        "La foto strappata rappresentava perfettamente lo stato del loro rapporto.",
        "L'email di rifiuto brillava sullo schermo, cancellando mesi di speranze.",
        "Il libro che le aveva dedicato giaceva intatto sullo scaffale, mai sfogliato.",
        "L'abito da sposa rimase nell'armadio, testimone silenzioso di sogni infranti.",
        "Lo sguardo del mentore rivelò che non era all'altezza delle aspettative.",
        "La medaglia di partecipazione pesava come un macigno nella sua mano.",
        "La sedia vuota al tavolo familiare gridava l'assenza che nessuno osava menzionare.",
        "Il progetto su cui aveva lavorato per mesi venne liquidato in due minuti di riunione.",
        "Contò i giorni sul calendario senza ricevere la telefonata promessa.",
        "L'appartamento dei suoi sogni venne venduto a qualcun altro mentre lui esitava.",
        "Le pagine del suo manoscritto tornarono piene di correzioni in rosso.",
        "Il messaggio 'Ci vediamo un'altra volta' sapeva di addio definitivo.",
        "Lo schermo del telefono rimaneva ostinatamente buio, senza notifiche.",
        "Guardò la sua opera d'arte, vedendo solo gli errori che nessun altro notava.",
        "Il contratto stracciato rappresentava anni di lavoro buttati al vento.",
        "La porta chiusa dell'ufficio del capo dopo il colloquio diceva tutto.",
        "La lettera di raccomandazione era tiepida, proprio come il loro rapporto.",
        "Fissò la casella email vuota il giorno in cui i risultati dovevano arrivare.",
        "Il palco dove avrebbe dovuto esibirsi venne smontato prima del suo turno.",
        "L'anello restituito sembrava più pesante di quando l'aveva donato.",
        "Il silenzio dell'aula dopo la sua presentazione parlava più di mille critiche.",
        "Vide online le foto della festa a cui non era stato invitato.",
        "La tela bianca lo fissava, ricordandogli l'ispirazione che non arrivava più.",
        "Il suo nome mancava dalla lista dei promossi affissa in bacheca.",
        "L'abbraccio di circostanza non nascondeva l'indifferenza nei suoi occhi.",
        "Il biglietto del treno non utilizzato era l'ultimo ricordo di un incontro mai avvenuto.",
        "Passò ore a fissare il telefono che non squillava mai.",
        "Riguardò il curriculum inviato a decine di aziende senza ricevere risposta.",
        "La sala conferenze semivuota durante il suo intervento raccontava la sua irrilevanza.",
        "Il profilo social dell'ex mostrava una felicità che con lui non aveva mai trovato.",
        "Ripercorse mentalmente la conversazione, cercando di capire dove avesse sbagliato.",
        "L'ultimo messaggio visualizzato ma senza risposta diceva tutto.",
        "Il piatto cucinato con cura venne a malapena assaggiato e poi abbandonato.",
        "Tutte le sue idee furono scartate durante il brainstorming aziendale.",
        "La critica al suo lavoro era stata tanto gentile quanto devastante.",
        "Le chiavi dell'ufficio riconsegnate segnavano la fine di un percorso professionale.",
        "Le scuse ripetute avevano ormai perso ogni significato.",
        "Gli applausi di cortesia alla fine della sua esibizione ferivano più del silenzio.",
        "Accarezzò la copertina del libro che nessun editore aveva voluto pubblicare.",
        "La bacheca dei ricordi conteneva solo frammenti di sogni mai realizzati.",
        "Il gruppo WhatsApp una volta pieno di messaggi ora taceva da settimane.",
        "Le luci della città vista dall'alto gli ricordavano quanto si sentisse solo.",
        "La notifica di rifiuto del prestito seppellì i suoi progetti imprenditoriali.",
        "Il suo contributo al progetto di gruppo non venne nemmeno menzionato nella presentazione finale.",
        "L'ennesimo 'forse la prossima volta' suonava come un rifiuto definitivo.",
        "Il biglietto d'auguri generico rivelava quanto poco la conoscessero.",
        "Le pagine del diario rimanevano bianche, incapaci di contenere tanta delusione.",
        "Il vestito comprato per l'occasione speciale rimase nell'armadio con l'etichetta ancora attaccata.",
        "Il suo nome venne pronunciato in modo sbagliato durante la cerimonia di premiazione.",
        "La proposta di matrimonio preparata nei minimi dettagli rimase nelle sue tasche.",
        "Osservò i like diminuire progressivamente sotto i suoi post.",
        "Il silenzio dopo la sua battuta in un gruppo di amici fu assordante.",
        "Lo champagne comprato per festeggiare rimase in frigo, mai stappato.",
        "Il tavolo prenotato per due rimase metà vuoto per tutta la serata.",
        "Il sogno nel cassetto si trasformò lentamente in un rimpianto.",
        "L'album delle foto di famiglia conteneva sempre meno immagini ogni anno.",
        "Il pianoforte accumulava polvere, proprio come il suo talento inutilizzato.",
        "La firma sul contratto sembrava ora una condanna invece che un'opportunità.",
        "Le congratulazioni forzate agli altri nascondevano un cuore spezzato.",
        "Il suo nome venne sistematicamente dimenticato nei ringraziamenti ufficiali.",
        "L'invito alla reunion arrivò troppo tardi per rimediare anni di assenza.",
        "Controllò l'orologio per l'ennesima volta, realizzando che non sarebbe arrivato nessuno.",
        "La dedica sul libro regalo era impersonale come un messaggio automatico.",
        "Il posto vuoto accanto a sé durante la cerimonia urlava la sua solitudine.",
        "Guardò il tramonto da solo sulla spiaggia dove avevano programmato di incontrarsi.",
        "I commenti sotto il suo post erano educati ma privi di entusiasmo reale.",
        "Lo specchio rifletteva un volto che non riconosceva più, segnato dalle delusioni.",
        "Il suo portafoglio progetti conteneva solo idee bocciate o mai realizzate.",
        "La mail di feedback era piena di critiche mascherate da suggerimenti costruttivi.",
        "L'assenza del suo nome tra i finalisti confermò i suoi peggiori timori.",
        "La telefonata tanto attesa si rivelò essere solo pubblicità telefonica.",
        "Il suo sforzo venne liquidato con un 'grazie, ma abbiamo scelto un'altra direzione'.",
        "Le pareti della casa nuova sembravano più vuote senza la persona amata.",
        "La menzione del suo nome provocò sguardi imbarazzati tra i presenti.",
        "Il test negativo di gravidanza segnò l'ennesima speranza infranta.",
        "La replica entusiasta preparata rimase non detta quando cambiarono argomento.",
        "I follower diminuivano giorno dopo giorno, così come la sua autostima.",
        "Il suo cv venne archiviato nella cartella 'da considerare in futuro'.",
        "La sua mano tesa non trovò nessuno dall'altra parte a stringerla.",
        "Il brindisi al suo successo venne posticipato a un futuro sempre più lontano.",
        "Rimase sveglio tutta la notte aspettando una chiamata che non arrivò mai.",
        "L'estratto conto bancario raccontava una storia di sogni troppo costosi.",
        "Passò in rassegna mentalmente tutte le persone che lo avevano abbandonato.",
        "Il suo quadro venne appeso nell'angolo meno visibile della galleria.",
        "Le pareti dell'appartamento sembravano restringersi ad ogni rifiuto ricevuto.",
        "Le notifiche dei social media erano piene di successi altrui e mai suoi.",
        "Il gesto gentile passò completamente inosservato da chi voleva impressionare.",
        "La conversazione si spense lentamente fino a diventare silenzio.",
        "Il profumo regalato rimase intatto sulla mensola, mai indossato.",
        "L'obiettivo segnato sulla lista dei desideri venne cancellato senza essere realizzato.",
        "Le sue battute nel gruppo venivano sistematicamente ignorate o fraintese.",
        "Il suo contributo alla discussione venne interrotto e mai ripreso.",
        "Le foto del viaggio mai fatto rimasero come sfondo del computer.",
        "Le congratulazioni che aspettava si trasformarono in un imbarazzante silenzio." ]

data = {
    "sentence": sentences_paura+sentences_amore+sentences_spavento+sentences_delusione,
    "label": [0]*len(sentences_paura)+[1]*len(sentences_amore)+[2]*len(sentences_spavento)+[3]*len(sentences_delusione),
    "idx": list(range(0, len(sentences_paura)+len(sentences_amore)+len(sentences_spavento)+len(sentences_delusione)))
}
# print how many paura,amore,spavento,delusione
print(f"paura: {len(sentences_paura)}")
print(f"amore: {len(sentences_amore)}")
print(f"spavento: {len(sentences_spavento)}")
print(f"delusione: {len(sentences_delusione)}")
# Out:
# paura: 95
# amore: 96
# spavento: 94
# delusione: 97

# %%
# Creare il Dataset da addestramento e validazione
dataset = Dataset.from_dict(data)

# Dividere il dataset train e  test
split = dataset.train_test_split(test_size=0.2, seed=42)

# DatasetDict
raw_datasets = DatasetDict({
    "train": split["train"],
    "validation": split["test"]
})

# Visualizza la struttura finale
print(raw_datasets)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 305
#     })
#     validation: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 77
#     })
# })

# %% [markdown]
# ## Model Tokenizer

# %%
#def compute_metrics(eval_preds):
#    metric = evaluate.load("glue", "mrpc")
#    logits, labels = eval_preds
#    predictions = np.argmax(logits, axis=-1)
#    return metric.compute(predictions=predictions, references=labels)

def tokenize_function(example):
    return tokenizer(example["sentence"], truncation=True)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, DataCollatorWithPadding
import evaluate
import numpy as np

#checkpoint = "bert-base-uncased"
checkpoint = "tabularisai/multilingual-sentiment-analysis" # distilbert/distilbert-base-multilingual-cased
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=len(classes), ignore_mismatched_sizes=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at tabularisai/multilingual-sentiment-analysis and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([5]) in the checkpoint and torch.Size([4]) in the model instantiated
# - classifier.weight: found shape torch.Size([5, 768]) in the checkpoint and torch.Size([4, 768]) in the model instantiated
# ...

# %%
tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# ...
# Map:   0%|          | 0/77 [00:00<?, ? examples/s]

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(eval_preds):
    """
    Compute metrics for evaluation.

    Args:
        eval_preds: A tuple (logits, labels) where logits are the model's outputs
                    and labels are the true labels.

    Returns:
        dict: A dictionary with the evaluation metrics (accuracy, precision, recall, F1 score).
    """
    # Unpack predictions and labels
    logits, labels = eval_preds

    # Convert logits to predicted class labels
    predictions = np.argmax(logits, axis=-1)

    # Calculate accuracy, precision, recall, and F1 score
    accuracy = accuracy_score(labels, predictions)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average="weighted")

    # Return metrics as a dictionary
    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1
    }

# %%
training_args = TrainingArguments("test-trainer", evaluation_strategy="epoch", num_train_epochs=10)
# training_args = TrainingArguments(
#     output_dir="test-trainer",          # Output directory
#     evaluation_strategy="epoch",    # Evaluate after each epoch
#     #learning_rate=2e-5,             # Learning rate
#     #per_device_train_batch_size=16, # Batch size for training
#     #per_device_eval_batch_size=16,  # Batch size for evaluation
#     num_train_epochs=3,             # Number of epochs
#     #weight_decay=0.01,              # Weight decay
#     #logging_dir="./logs",           # Directory for logs
#     #logging_steps=10,               # Log every 10 steps
#     #save_total_limit=2,             # Save only the last 2 checkpoints
#     #save_steps=500,                 # Save every 500 steps
# )

trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-8-b3c82a45ce4b>:16: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
import wandb
wandb.init(mode="disabled")
# https://huggingface.co/docs/datasets/v1.13.0/quickstart.html
# https://huggingface.co/docs/transformers/main_classes/trainer
# https://huggingface.co/learn/nlp-course/chapter7/3
#os.environ["WANDB_DISABLED"] = "true"
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#     <div>
#
#       <progress value='390' max='390' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [390/390 00:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.798453</td>
#       <td>0.727273</td>
#       <td>0.779094</td>
#       <td>0.727273</td>
#       <td>0.725057</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.517964</td>
# ...

# %% [markdown]
# ## Validation Confusion  Matrix

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch
import torch.nn.functional as F

#model_path = "/content/test-trainer/checkpoint-15"  # Occhi a prendere il checkpoint GIUSTO
model_path = "/content/test-trainer/checkpoint-390"  # Occhi a prendere il checkpoint GIUSTO
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)

# %%
from sklearn.metrics import confusion_matrix
import torch

# Assuming 'classes' is a list of class labels and 'model', 'tokenizer' are defined
true_labels = []
predicted_labels = []

d = raw_datasets["validation"]["sentence"]
for i in range(len(d)):
    label = classes[raw_datasets["validation"]["label"][i]]
    sentences = [d[i]]
    #torch.set_grad_enabled(False)  # Disable gradients for inference
    token_inputs = tokenizer(sentences, return_tensors="pt", padding=True, truncation=True)  # Ensure tensor shapes are correct
    inputs = {k: v.to(model.device) for k, v in token_inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    probabilities = torch.softmax(logits, dim=-1)
    for sentence, probs in zip(sentences, probabilities):
        predicted_class = torch.argmax(probs, dim=-1)
        label_pred = classes[predicted_class.item()]
        true_labels.append(raw_datasets["train"]["label"][i])
        predicted_labels.append(predicted_class.item())
        if label_pred != label:
            print(f"{label}: Pred: {label_pred}: {probs[predicted_class.item()]:.3f}: {sentence} {probs}")
# Out:
# Paura: Pred: Spavento: 0.999: Il suono di unghie che grattavano contro il muro la fece raggelare sotto le coperte. tensor([7.3036e-04, 2.4927e-04, 9.9884e-01, 1.7558e-04])
# Delusione: Pred: Paura: 0.998: L'abbraccio di circostanza non nascondeva l'indifferenza nei suoi occhi. tensor([9.9799e-01, 3.0006e-04, 2.9551e-04, 1.4135e-03])
# Paura: Pred: Spavento: 0.996: Lo scricchiolio della porta che si apriva lentamente la inchiodò contro il muro. tensor([3.2220e-03, 1.7378e-04, 9.9637e-01, 2.3039e-04])
# Paura: Pred: Spavento: 0.999: La ragnatela che le sfiorò il viso nell'oscurità le strappò un grido soffocato. tensor([5.1823e-04, 2.1104e-04, 9.9905e-01, 2.1751e-04])
# Spavento: Pred: Paura: 0.672: Il giocattolo che si attivò da solo nel cuore della notte la fece sedere di scatto nel letto. tensor([0.6724, 0.0010, 0.3255, 0.0012])
# Amore: Pred: Paura: 0.995: Il tocco delle sue dita sulla pelle era come una carezza dell'anima. tensor([9.9468e-01, 2.4739e-03, 3.7441e-04, 2.4686e-03])
# ...

# %%
import plotly.express as px
import pandas as pd

c = list(classes.values())
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels, labels=list(classes.keys()))

# Convert to DataFrame for Plotly
cm_df = pd.DataFrame(cm, index=c, columns=c)

# Plot the confusion matrix using Plotly
fig = px.imshow(cm_df, text_auto=True, aspect="auto",
                labels=dict(x="Predicted Label", y="True Label", color="Count"),
                x=c, y=c, color_continuous_scale="Blues")
fig.update_layout(title='Confusion Matrix')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Inference on single sentence

# %%
from sklearn.metrics import confusion_matrix
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch
import torch.nn.functional as F

model_path = "/content/test-trainer/checkpoint-390"  # Occhi a prendere il checkpoint GIUSTO
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)


sentences = ["La lezione è finita! che peccato"]
sentences = ["Oggi non so superato l'esame"]
sentences = ["Oggi mi è caduto il bilanciere a due passi da viso, sono salvo"]
sentences = ["mi sto innamorando"]
sentences = ["sei dolcissima"]

token_inputs = tokenizer(sentences, return_tensors="pt", padding=True, truncation=True)  # Ensure tensor shapes are correct
inputs = {k: v.to(model.device) for k, v in token_inputs.items()}
with torch.no_grad():
    outputs = model(**inputs)
logits = outputs.logits
probabilities = torch.softmax(logits, dim=-1)
for sentence, probs in zip(sentences, probabilities):
    predicted_class = torch.argmax(probs, dim=-1)
    label_pred = classes[predicted_class.item()]
    print(f"Pred: {label_pred}: {probs[predicted_class.item()]:.3f}: {sentence} {probs}")
# Out:
# Pred: Amore: 0.904: sei dolcissima tensor([0.0586, 0.9043, 0.0171, 0.0201])
